# %% [markdown]
# # K-means clustering_ Image identification
# You will use an image.dogs.jpeg in this assigmnet and implement k-means clustering for image segmentation and identify dominant color in the image

# %% [markdown]
# # Question:
#     1.Open and display the image “dog.jpeg”. Convert the image in to numpy array,so that it can be used in further processing.[Hint:Use PIL module from python]
#     2. Find out the dimensions of the image and convert it in to a two-dimensional array.
#     3.Use kmeans clustering with k set to 3 and cluster the image.[Hint: Refer to k-means module of scikit learn]
#     4. Predict thecluster label of every pixel in the image and plot it back as an image.
#     5. Find out the three dominant color in the image.[Hint: The cluster centers should correspond to three dominant colors]

# %%
from PIL import Image
from sklearn.cluster import KMeans

# %%
import os
os.chdir(r'C:\Users\je638474\Documents\JJ\Folders\Udemy\Python EDUREKA')
image = Image.open('dogs.jpeg')

# %%
from matplotlib import pyplot as plot

# %matplotlib inline

plot.imshow(image)

# %%
import numpy as np

image_np = np.asarray(image)

# %%
image_np.shape
# Out:
# (185, 272, 3)

# %%
image_np = image_np.reshape((185*272,3))

# %%
image_np.shape
# Out:
# (50320, 3)

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(image_np)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(image_np)

# %%
labels = labels.reshape((185,272))

# %%
plot.imshow(labels)

# %%
centers = [centers.astype(int) for centers in kmeans.cluster_centers_]

# %%
blob = np.ones((100,100,3))

# %%
blob1 = blob * centers[0]

# %%
plot.imshow(blob1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2 = blob * centers[1]
plot.imshow(blob2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blob2=blob2.astype(int)
blob2
# Out:
# array([[[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]],
#
#        [[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]],
#
#        [[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]],
#
#        ...,
#
#        [[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]],
#
#        [[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]],
#
#        [[29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20],
#         ...,
#         [29, 21, 20],
#         [29, 21, 20],
#         [29, 21, 20]]])

# %%
blob3 = blob * centers[2]
plot.imshow(blob3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
centers
# Out:
# [array([210, 174, 143]), array([29, 21, 20]), array([251, 247, 243])]
